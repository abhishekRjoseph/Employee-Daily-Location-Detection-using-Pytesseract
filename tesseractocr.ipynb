# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd=r'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# %%
 import cv2

# %%
img=cv2.imread(r'C:\Users\hp\Desktop\WhatsApp Image 2022-11-07 at 11.46.52.jpeg')
cv2.imshow('sample image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
text=pytesseract.image_to_string(img)
print(text)

# %%
# extract text from all the images in a folder
# storing the text in a single file
from PIL import Image
import pytesseract as pt
import os
	
def main():
	# path for the folder for getting the raw images
	path =r"C:\Users\hp\Desktop\python practice\New folder\New Folder (5)"

	# link to the file in which output needs to be kept
	fullTempPath =r"C:\Users\hp\Desktop\python practice\New folder\tesseract.txt"

	# iterating the images inside the folder
	for imageName in os.listdir(path):
		inputPath = os.path.join(path, imageName)
		img = Image.open(inputPath)

		# applying ocr using pytesseract for python
		text = pt.image_to_string(img, lang ="eng")

		# saving the text for appending it to the output.txt file
		# a + parameter used for creating the file if not present
		# and if present then append the text content
		file1 = open(fullTempPath, "a+")

		# providing the name of the image
		file1.write(imageName+"\n")

		# providing the content in the image
		file1.write(text+"\n")
		file1.close()

	# for printing the output file
	file2 = open(fullTempPath, 'r')
	print(file2.read())
	file2.close()		


if __name__ == '__main__':
	main()
# Out:
# WhatsApp Image 2022-11-07 at 09.55.14.jpeg
# : QO GPS Map Camera
#
# Meerut, Uttar Pradesh, India
# XMCM+3WG, Guru Nanak Nagar, Beripura,
# Meerut, Uttar Pradesh 250002, India
#
# Lat 28.970109°
#
# Long 77.685075°
#
# 03/11/22 03:24 PM GMT +05:30
#
#
# WhatsApp Image 2022-11-07 at 09.55.20 (1).jpeg
# y Pepe rbar, West Behe, India
# GJ96+274, Bhangar College Rd,
#
# j Lat 22.517488°
# Long 88:610707°
# 03/11/22 03:03 PM
#
# WhatsApp Image 2022-11-07 at 09.55.20.jpeg
# ee
# a GPS Map Camera
#
# | Lucknow, Uttar Pradesh, India
#
# ) 2/302, Rajni Khand, Sharda Nagar,
#
# Lucknow, Uttar Pradesh 226009, India eS
# Lat 26.778594° f
# Long 80.934905°
#
# 03/11/22 02:44 PM
# A PS a a a a 5 ag
#
#
# WhatsApp Image 2022-11-07 at 09.55.21 (1).jpeg
# RAL sTORE
# x] ae 311)
#
# NEW
# SINDHU
# NAGAR
#
# & KRISHNA NAGAR
# 4 Lucknow
# * Cont. Us.: 9140661420
#
# \
#
# a GPS Map Camera
#
# Lucknow, Uttar Pradesh, India
#
# RV2P+9Qx, Ashutosh Nagar, Krishna Nagar,
# ...

# %%
import pytesseract
from PIL import Image
import re, os
import pandas as pd

dirpath = r"C:\Users\hp\Desktop\python practice\New folder\New Folder (5)"
pytesseract.pytesseract.tesseract_cmd = 'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

lats, lons = [],[]
df = pd.DataFrame()
correct, incorrect = 0, 0
for imgfile in os.listdir(dirpath):
    img = Image.open(dirpath + "\\" + imgfile)
    imgtext = pytesseract.image_to_string(img)
    try:
        lat, lon = re.findall(r'Lat\s*\d*.\d*', imgtext)[0].split()[1], re.findall(r'Long\s*\d*.\d*', imgtext)[0].split()[1]
        correct = correct + 1
        print(lat, lon)
        lats.append(lat)
        lons.append(lon)
    except Exception as e:
        print("Something went wrong with file = ", imgfile, " .Will ignore and continue")
        print(e)
        incorrect = incorrect + 1
        continue

df['Lat'] = lats
df['Long'] = lons
df.to_csv("LatLongData.csv")
print("Correct =", correct, " \nIncorrect =", incorrect)
# Out:
# 28.970109 77.685075
# 22.517488 88:610707
# 26.778594 80.934905
# 26.801072 80.886873
# 22.621184 88.335318
# 28.991634 77.701334
# 22.517133 88.609444
# 28.991607 77.700953
# 22.502675 88.615865
# 26.805884 80.88691
# 28.991729 77.700603
# 22.536773 88.372462
# 26.484082 80.25159
# 28.99132 77.732407
# 22.536878 88.372465
# 22.503802 88.563527
# 22.585884 88.331355
# 22.537227 88.369634
# 22.31729 88.267109
# 26.801386 80.894326
# 22.238308 88.27205
# 28.961977 77.682065
# Something went wrong with file =  WhatsApp Image 2022-11-07 at 09.55.31 (1).jpeg  .Will ignore and continue
# list index out of range
# 28.970975 77.661833
# 22.505918 88.539404
# 26.428918 80.323574
# 28.986373 77.732955
# Something went wrong with file =  WhatsApp Image 2022-11-07 at 09.55.57.jpeg  .Will ignore and continue
# list index out of range
# 26.425516 80.279813
# 22.238297 88.27209
# Something went wrong with file =  WhatsApp Image 2022-11-07 at 09.56.01.jpeg  .Will ignore and continue
# ...
